# %% [markdown]
# <a href="https://colab.research.google.com/github/Milchelle/Probabilidade_Estatistica/blob/main/Lista6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DISCIPLINA: PROBABILIDADE E ESTATISTICA
# ALUNO: MICHELLE LUCENA BRITO
# LISTA 6

#QUESTÃO 01
'''import pandas as pd # importa da biblioteca pandas
dados = {'Matemática': [60, 58, 73, 51, 54, 75, 48, 72, 75, 83, 62, 52], 
         'Música': [80, 62, 70, 83, 62, 92, 79, 88, 54, 82, 64, 69]} # Mostra os dados em forma de dicionario
a = pd.DataFrame (dados, columns = ['Matemática','Música']) # Seleciona as colunas 
Corr = a.corr() # Calcula a correlação
print('O COEFICIENTE DE CORRELAÇÃO DE É:')
print(Corr) # Exibe na tela o coeficiente de correlação ''' 

#QUESTÃO 02 (A): EXISTE UMA CORRELAÇÃO DESPREZÍVEL ENTRE A IDADE DA EDIÇÃO E O NÚMERO DE PÁGINAS DO LIVRO.

#QUESTÃO 03
'''import pandas as pd 
dados = {'x': [2, 3, 4, 5, 4, 6, 7, 8, 8, 10], 
         'y': [48, 50, 56, 52, 43, 60, 62, 58, 64, 72]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE É:')
print(Corr)'''

#QUESTÃO 4
'''import pandas as pd 
dados = {'x': [12, 16, 18, 20, 28, 30, 40, 48, 50, 54], 'y': [7.2, 7.4, 7.0, 6.5, 6.6, 6.7, 6.0, 5.6, 6.0, 5.5]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE É:')
print(Corr)'''

#QUESTÃO 05
'''print('CONJUNTO 1:')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
print('A MÉDIA DE X É:', statistics.mean(x),'E A MÉDIA DE Y É:', round(statistics.mean(y),2))
print('O DESVIO PADRÃO DE X É:', round(statistics.stdev(x),2),'E O DESVIO PADRÃO DE Y É:', round(statistics.stdev(y),2))

import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE x E y É:')
print(Corr)


print('CONJUNTO 2:')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
print('A MÉDIA DE X É:', statistics.mean(x),'E A MÉDIA DE Y É:', round(statistics.mean(y),2))
print('O DESVIO PADRÃO DE X É:', round(statistics.stdev(x),2),'E O DESVIO PADRÃO DE Y É:', round(statistics.stdev(y),2))

import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE x E y É:')
print(Corr)


print('CONJUNTO 3:')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
print('A MÉDIA DE X É:', statistics.mean(x),'E A MÉDIA DE Y É:', round(statistics.mean(y),2))
print('O DESVIO PADRÃO DE X É:', round(statistics.stdev(x),2),'E O DESVIO PADRÃO DE Y É:', round(statistics.stdev(y),2))

import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE x E y É:')
print(Corr)


print('CONJUNTO 4:')
import statistics
x = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
print('A MÉDIA DE X É:', statistics.mean(x),'E A MÉDIA DE Y É:', round(statistics.mean(y),2))
print('O DESVIO PADRÃO DE X É:', round(statistics.stdev(x),2),'E O DESVIO PADRÃO DE Y É:', round(statistics.stdev(y),2))

import pandas as pd
dados = {'x': [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], 'y': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
a = pd.DataFrame (dados, columns = ['x','y'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO DE x E y É:')
print(Corr)'''

#QUESTÃO 6
'''import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Alimentação': [4, 5, 1, 3, 6, 2]}
a = pd.DataFrame (dados, columns = ['Produtividade','Alimentação'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO LINEAR É:')
print(Corr)
sn.heatmap(Corr, annot=True)
plt.show()

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Exercícios': [1, 3, 2, 4, 5, 6]}
a = pd.DataFrame (dados, columns = ['Produtividade','Exercícios'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO LINEAR É:')
print(Corr)
sn.heatmap(Corr, annot=True)
plt.show()

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Rodízio': [3, 1, 2, 6, 4, 5]}
a = pd.DataFrame (dados, columns = ['Produtividade','Rodízio'])
Corr = a.corr()
print('O COEFICIENTE DE CORRELAÇÃO LINEAR É:')
print(Corr)
sn.heatmap(Corr, annot=True)
plt.show()'''
